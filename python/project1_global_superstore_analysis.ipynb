# %%
import pandas as pd
import numpy as np

# %%
orders = pd.read_csv("global_superstore_2016_orders.csv")
people = pd.read_csv("global_superstore_2016_people.csv")
returns = pd.read_csv("global_superstore_2016_returns.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 orders = pd.read_csv("global_superstore_2016_orders.csv")
#       2 people = pd.read_csv("global_superstore_2016_people.csv")
#       3 returns = pd.read_csv("global_superstore_2016_returns.csv")
#
# ...

# %%
# Make sure the CSV files are in the correct location
# Option 1: Provide the full path to the files
orders = pd.read_csv("/path/to/your/global_superstore_2016_orders.csv")
people = pd.read_csv("/path/to/your/global_superstore_2016_people.csv")
returns = pd.read_csv("/path/to/your/global_superstore_2016_returns.csv")

# Option 2: Upload the files to your Jupyter environment first
# Then read them from the current directory
# from google.colab import files  # Uncomment if using Google Colab
# uploaded = files.upload()  # This will prompt you to upload the files

# Option 3: Download the files directly if they're available online
# import urllib.request
# urllib.request.urlretrieve("https://example.com/global_superstore_2016_orders.csv", 
#                           "global_superstore_2016_orders.csv")
# urllib.request.urlretrieve("https://example.com/global_superstore_2016_people.csv", 
#                           "global_superstore_2016_people.csv")
# urllib.request.urlretrieve("https://example.com/global_superstore_2016_returns.csv", 
#                           "global_superstore_2016_returns.csv")
# orders = pd.read_csv("global_superstore_2016_orders.csv")
# people = pd.read_csv("global_superstore_2016_people.csv")
# returns = pd.read_csv("global_superstore_2016_returns.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Make sure the CSV files are in the correct location
#       2 # Option 1: Provide the full path to the files
# ----> 3 orders = pd.read_csv("/path/to/your/global_superstore_2016_orders.csv")
#       4 people = pd.read_csv("/path/to/your/global_superstore_2016_people.csv")
#       5 returns = pd.read_csv("/path/to/your/global_superstore_2016_returns.csv")
#
# ...

# %%
orders = pd.read_csv("orders.csv")
people = pd.read_csv("people.csv")
returns = pd.read_csv("returns.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 orders = pd.read_csv("orders.csv")
#       2 people = pd.read_csv("people.csv")
#       3 returns = pd.read_csv("returns.csv")
#
# ...

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Drrajan04

# %%
orders = pd.read_csv("orders.csv")
people = pd.read_csv("people.csv")
returns = pd.read_csv("returns.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 orders = pd.read_csv("orders.csv")
#       2 people = pd.read_csv("people.csv")
#       3 returns = pd.read_csv("returns.csv")
#
# ...

# %%
os.chdir(r"C:\Users\Drrajan04\Downloads")

# %%
orders = pd.read_csv("orders.csv")
people = pd.read_csv("people.csv")
returns = pd.read_csv("returns.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 orders = pd.read_csv("orders.csv")
#       2 people = pd.read_csv("people.csv")
#       3 returns = pd.read_csv("returns.csv")
#
# ...

# %%
orders = pd.read_csv("orders.csv")
people = pd.read_csv("people.csv")
returns = pd.read_csv("returns.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 orders = pd.read_csv("orders.csv")
#       2 people = pd.read_csv("people.csv")
#       3 returns = pd.read_csv("returns.csv")
#
# ...

# %%
pd.read_csv().
# Out:
#   Cell In[12], line 1
#     pd.read_csv().
#                   ^
# SyntaxError: invalid syntax

# %%
import os
os.chdir(r"C:\Users\Drrajan04\Downloads")  # folder where CSVs exist

# %%
orders = pd.read_csv("orders.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 orders = pd.read_csv("orders.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Drrajan04\Downloads

# %%
print(os.listdir())
# Out:
# ['00047.MTS', '028bab097215a32126b44cb9f9fdbab6.jpg', '05 Mangala Sutta in Pali Hindi and English (1).pdf', '05 Mangala Sutta in Pali Hindi and English.pdf', '1 SF (1).pdf', '1 SF (2).pdf', '1 SF.pdf', '1-s2.0-S2352146518306203-main (1).pdf', '1-s2.0-S2352146518306203-main (2).pdf', '1-s2.0-S2352146518306203-main (3) (1).pdf', '1-s2.0-S2352146518306203-main (3).pdf', '1-s2.0-S2352146518306203-main (4).pdf', '1-s2.0-S2352146518306203-main.pdf', '1.jpeg', '10.1080@19427867.2018.1563268 (1).pdf', '10.1080@19427867.2018.1563268 (2).pdf', '10.1080@19427867.2018.1563268 (3).pdf', '10.1080@19427867.2018.1563268 (4).pdf', '10.1080@19427867.2018.1563268.pdf', '11. Road safety.pdf', '117989841.pdf', '1601992202384_RAIMA RAJAN XI -A.pdf', '1640252611897_27976.pdf', '17-06803_IN02_08022016053610 (1).pdf', '17-06803_IN02_08022016053610 (2).pdf', '17-06803_IN02_08022016053610.pdf', '17321972588247179451769873345435.jpg', '18. Sample Superstore for M Functions.xlsx', '1_a4e6a945-4e35-4a58-931c-4251
# ...

# %%
print(os.listdir())
# Out:
# ['00047.MTS', '028bab097215a32126b44cb9f9fdbab6.jpg', '05 Mangala Sutta in Pali Hindi and English (1).pdf', '05 Mangala Sutta in Pali Hindi and English.pdf', '1 SF (1).pdf', '1 SF (2).pdf', '1 SF.pdf', '1-s2.0-S2352146518306203-main (1).pdf', '1-s2.0-S2352146518306203-main (2).pdf', '1-s2.0-S2352146518306203-main (3) (1).pdf', '1-s2.0-S2352146518306203-main (3).pdf', '1-s2.0-S2352146518306203-main (4).pdf', '1-s2.0-S2352146518306203-main.pdf', '1.jpeg', '10.1080@19427867.2018.1563268 (1).pdf', '10.1080@19427867.2018.1563268 (2).pdf', '10.1080@19427867.2018.1563268 (3).pdf', '10.1080@19427867.2018.1563268 (4).pdf', '10.1080@19427867.2018.1563268.pdf', '11. Road safety.pdf', '117989841.pdf', '1601992202384_RAIMA RAJAN XI -A.pdf', '1640252611897_27976.pdf', '17-06803_IN02_08022016053610 (1).pdf', '17-06803_IN02_08022016053610 (2).pdf', '17-06803_IN02_08022016053610.pdf', '17321972588247179451769873345435.jpg', '18. Sample Superstore for M Functions.xlsx', '1_a4e6a945-4e35-4a58-931c-4251
# ...

# %%
orders = pd.read_csv("orders.csv")
people = pd.read_csv("people.csv")
returns = pd.read_csv("returns.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 orders = pd.read_csv("orders.csv")
#       2 people = pd.read_csv("people.csv")
#       3 returns = pd.read_csv("returns.csv")
#
# ...

# %%
orders = pd.read_csv("orders.csv")
people = pd.read_csv("people.csv")
returns = pd.read_csv("returns.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 orders = pd.read_csv("orders.csv")
#       2 people = pd.read_csv("people.csv")
#       3 returns = pd.read_csv("returns.csv")
#
# ...

# %%
orders = pd.read_csv("orders.csv", encoding="latin1")
people = pd.read_csv("people.csv", encoding="latin1")
returns = pd.read_csv("returns.csv", encoding="latin1")

# %%
orders.head()
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   Postal Code     9994 non-null   float64
#  9   City            51290 non-null  object
#  10  State           51290 non-null  object
#  11  Country         51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Market          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...
